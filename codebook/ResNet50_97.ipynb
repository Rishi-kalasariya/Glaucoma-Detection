# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Input, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
# Change VGG16 import to ResNet50
from tensorflow.keras.applications import ResNet50
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2025-04-22 01:28:10.872065: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-22 01:28:10.874539: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-22 01:28:10.881240: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745265490.892173   78923 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745265490.895496   78923 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745265490.904089   78923 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745265490.904098   78923 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745265490.904099   78923 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745265490.904100   78923 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-22 01:28:10.907198: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Check if previously saved models exist
cnn_model_path = "glaucoma_cnn_model_acrima.keras"
resnet_model_path = "glaucoma_resnet50_model_acrima.keras"

if os.path.exists(cnn_model_path):
    print("Loading existing CNN model...")
    cnn_model = tf.keras.models.load_model(cnn_model_path)
    SKIP_CNN_TRAINING = True
else:
    print("No existing CNN model found. Will train a new CNN model.")
    SKIP_CNN_TRAINING = False

# Update the model path check for ResNet50
if os.path.exists(resnet_model_path):
    print("Loading existing ResNet50 model...")
    resnet_model = tf.keras.models.load_model(resnet_model_path)
    SKIP_RESNET_TRAINING = True
else:
    print("No existing ResNet50 model found. Will train a new ResNet50 model.")
    SKIP_RESNET_TRAINING = False
# Out:
# No existing CNN model found. Will train a new CNN model.
# No existing ResNet50 model found. Will train a new ResNet50 model.

# %%
# Set image dimensions - ResNet50 also uses 224x224
img_height, img_width = 224, 224

def load_and_preprocess_dataset(dataset_name, base_path="dataset"):
    """Load and preprocess images from a dataset"""
    images_glaucoma = []
    images_normal = []

    for category, image_list in zip(["glaucoma", "normal"], [images_glaucoma, images_normal]):
        dataset_path = os.path.join(base_path, dataset_name, category)

        if not os.path.exists(dataset_path):
            print(f"Dataset path for {dataset_name}/{category} not found.")
            continue

        image_files = [f for f in os.listdir(dataset_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        # Load, convert color, resize, and normalize in one step
        image_list.extend([
            cv2.resize(
                cv2.cvtColor(cv2.imread(os.path.join(dataset_path, img_name)), cv2.COLOR_BGR2RGB),
                (img_height, img_width)
            ) / 255.0
            for img_name in image_files
        ])

    print(f"{dataset_name} images loaded and preprocessed successfully.")
    return np.array(images_glaucoma), np.array(images_normal)

# %%
def display_dataset_samples(dataset_name, images_glaucoma, images_normal, num_samples=4):
    """Display sample images from each category"""
    categories = ["Glaucoma", "Normal"]
    image_lists = [images_glaucoma, images_normal]

    for category, image_list in zip(categories, image_lists):
        if len(image_list) == 0:
            print(f"No images available for {dataset_name} - {category}")
            continue

        # Randomly select images (avoiding errors if list has fewer images)
        sample_images = random.choices(image_list, k=min(num_samples, len(image_list)))

        print(f"\nSample {dataset_name} {category} images:")
        plt.figure(figsize=(15, 10))

        for i, img in enumerate(sample_images):
            plt.subplot(1, num_samples, i + 1)
            # Since images are already normalized (0-1), we can display them directly
            plt.imshow(img)
            plt.axis("off")

        plt.show()

# %%
acrima_glaucoma, acrima_normal = load_and_preprocess_dataset("ACRIMA")
display_dataset_samples("ACRIMA", acrima_glaucoma, acrima_normal, num_samples=5)
print(f"ACRIMA - Glaucoma: {acrima_glaucoma.shape}, Normal: {acrima_normal.shape}")
# Out:
# ACRIMA images loaded and preprocessed successfully.
#
# Sample ACRIMA Glaucoma images:
# Sample ACRIMA Normal images:
# ACRIMA - Glaucoma: (396, 224, 224, 3), Normal: (309, 224, 224, 3)

# %%
# Print total images in each category
print(f"Total Glaucoma images: {len(acrima_glaucoma)}")
print(f"Total Normal images: {len(acrima_normal)}")

# Define class names and their counts
dataset_classes = np.array(["Glaucoma", "Normal"])
data_count = [len(acrima_glaucoma), len(acrima_normal)]

# Print total counts
print(f"Total images: {sum(data_count)}")
for category, count in zip(dataset_classes, data_count):
    print(f"Total {category} images: {count}")

# Plot class distribution
sns.set_style("darkgrid")
plt.figure(figsize=(6, 4))
sns.barplot(x=dataset_classes, y=data_count, hue=dataset_classes)
plt.xlabel("Category")
plt.ylabel("Number of Images")
plt.title("Distribution of Glaucoma & Normal Images")
plt.show()
# Out:
# Total Glaucoma images: 396
# Total Normal images: 309
# Total images: 705
# Total Glaucoma images: 396
# Total Normal images: 309

# %%
# Split data into train, validation and test sets
train_ratio = 0.8
val_ratio = 0.1  # Since test is 10%, val is also 10%

# Splitting Glaucoma images
X_train_glaucoma, temp_glaucoma = train_test_split(acrima_glaucoma, test_size=(1 - train_ratio), random_state=42)
X_val_glaucoma, X_test_glaucoma = train_test_split(temp_glaucoma, test_size=0.5, random_state=42)

# Splitting Normal images
X_train_normal, temp_normal = train_test_split(acrima_normal, test_size=(1 - train_ratio), random_state=42)
X_val_normal, X_test_normal = train_test_split(temp_normal, test_size=0.5, random_state=42)

# Print split counts
print(f"Train - Glaucoma: {len(X_train_glaucoma)}, Normal: {len(X_train_normal)}")
print(f"Validation - Glaucoma: {len(X_val_glaucoma)}, Normal: {len(X_val_normal)}")
print(f"Test - Glaucoma: {len(X_test_glaucoma)}, Normal: {len(X_test_normal)}")
# Out:
# Train - Glaucoma: 316, Normal: 247
# Validation - Glaucoma: 40, Normal: 31
# Test - Glaucoma: 40, Normal: 31

# %%
# Combine datasets and create labels
X_train = np.concatenate((X_train_glaucoma, X_train_normal), axis=0)
y_train = np.concatenate((np.ones(len(X_train_glaucoma)), np.zeros(len(X_train_normal))))

X_val = np.concatenate((X_val_glaucoma, X_val_normal), axis=0)
y_val = np.concatenate((np.ones(len(X_val_glaucoma)), np.zeros(len(X_val_normal))))

X_test = np.concatenate((X_test_glaucoma, X_test_normal), axis=0)
y_test = np.concatenate((np.ones(len(X_test_glaucoma)), np.zeros(len(X_test_normal))))

# Convert to categorical (one-hot encoding)
y_train_cat = to_categorical(y_train, num_classes=2)
y_val_cat = to_categorical(y_val, num_classes=2)
y_test_cat = to_categorical(y_test, num_classes=2)

# Define data augmentation (enhanced version for both models)
datagen = ImageDataGenerator(
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
)

# Prepare augmentation (required for the generator)
datagen.fit(X_train)

# %%
# Create TensorFlow datasets for training, validation, and testing for CNN model
# For training data (with augmentation)
def train_generator_fn(batch_size=32):
    return datagen.flow(X_train, y_train_cat, batch_size=batch_size, shuffle=True)

cnn_train_ds = tf.data.Dataset.from_generator(
    lambda: train_generator_fn(32),
    output_signature=(
        tf.TensorSpec(shape=(None, img_height, img_width, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, 2), dtype=tf.float32)
    )
).prefetch(tf.data.AUTOTUNE)

# For validation data (NO augmentation)
cnn_val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val_cat)).batch(32).prefetch(tf.data.AUTOTUNE)

# For test data (NO augmentation)
cnn_test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test_cat)).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
if not SKIP_CNN_TRAINING:
    # Define the CNN model
    cnn_model = Sequential()

    # Input Layer
    cnn_model.add(Input(shape=(img_height, img_width, 3)))

    # Convolutional and Pooling Layers (filters increasing deeper)
    cnn_model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

    cnn_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

    cnn_model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flattening Layer
    cnn_model.add(Flatten())

    # Fully Connected Layers
    cnn_model.add(Dense(512, activation='relu'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Dropout(0.4))

    cnn_model.add(Dense(256, activation='relu'))
    cnn_model.add(Dropout(0.4))

    # Output Layer
    cnn_model.add(Dense(units=2, activation='softmax'))  # 2 classes (glaucoma, normal)

    # Compile the model
    cnn_model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

    # Model summary
    print("CNN Model Architecture:")
    cnn_model.summary()
else:
    # Just display the model summary
    print("CNN Model Architecture (loaded from disk):")
    cnn_model.summary()
# Out:
# CNN Model Architecture:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 224, 224, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 512)            │    25,690,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,848,546 (98.60 MB)
#  Trainable params: 25,847,298 (98.60 MB)
#  Non-trainable params: 1,248 (4.88 KB)

# %%
if not SKIP_CNN_TRAINING:
    # Calculate steps per epoch based on dataset size and batch size
    batch_size = 32
    steps_per_epoch = np.ceil(len(X_train)/batch_size).astype(int)

    # Train the model using tf.data.Dataset
    cnn_history = cnn_model.fit(
        cnn_train_ds,
        steps_per_epoch=steps_per_epoch,
        epochs=150,
        validation_data=cnn_val_ds,
        verbose=1
    )

    # Save the model after training
    cnn_model.save(cnn_model_path)
    print("CNN Model saved!")
else:
    # Create an empty history object to avoid errors in the plotting cell
    class EmptyHistory:
        def __init__(self):
            self.history = {'accuracy': [], 'val_accuracy': [], 'loss': [], 'val_loss': []}
    cnn_history = EmptyHistory()
    print("Skipped CNN training as model was loaded from disk.")
# Out:
# Epoch 1/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 14s 679ms/step - accuracy: 0.7189 - loss: 0.8632 - val_accuracy: 0.5634 - val_loss: 0.6620
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 670ms/step - accuracy: 0.9283 - loss: 0.1997 - val_accuracy: 0.5634 - val_loss: 0.7469
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9393 - loss: 0.1802 - val_accuracy: 0.5634 - val_loss: 0.9504
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9418 - loss: 0.1798 - val_accuracy: 0.5634 - val_loss: 1.0594
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 668ms/step - accuracy: 0.9583 - loss: 0.1645 - val_accuracy: 0.5634 - val_loss: 1.3496
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 665ms/step - accuracy: 0.9505 - loss: 0.1370 - val_accuracy: 0.5634 - val_loss: 1.4515
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 665ms/step - accuracy: 0.9434 - loss: 0.1433 - val_accuracy: 0.5634 - val_loss: 1.6189
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9449 - loss: 0.1329 - val_accuracy: 0.5634 - val_loss: 1.6145
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9628 - loss: 0.0889 - val_accuracy: 0.5634 - val_loss: 1.6616
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 651ms/step - accuracy: 0.9681 - loss: 0.0907 - val_accuracy: 0.5634 - val_loss: 1.6887
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 650ms/step - accuracy: 0.9410 - loss: 0.1743 - val_accuracy: 0.5634 - val_loss: 1.6513
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 650ms/step - accuracy: 0.9696 - loss: 0.0635 - val_accuracy: 0.5634 - val_loss: 1.6457
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 651ms/step - accuracy: 0.9663 - loss: 0.1002 - val_accuracy: 0.5634 - val_loss: 1.6499
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9720 - loss: 0.0707 - val_accuracy: 0.5634 - val_loss: 1.5048
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9689 - loss: 0.0775 - val_accuracy: 0.5634 - val_loss: 2.0440
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9855 - loss: 0.0538 - val_accuracy: 0.5634 - val_loss: 2.0074
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.9619 - loss: 0.1071 - val_accuracy: 0.5634 - val_loss: 1.6680
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.9749 - loss: 0.0568 - val_accuracy: 0.5915 - val_loss: 1.8220
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.9871 - loss: 0.0446 - val_accuracy: 0.5634 - val_loss: 1.8439
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9870 - loss: 0.0413 - val_accuracy: 0.6197 - val_loss: 1.3335
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9837 - loss: 0.0574 - val_accuracy: 0.6479 - val_loss: 1.1597
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9722 - loss: 0.0754 - val_accuracy: 0.6479 - val_loss: 1.1540
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9859 - loss: 0.0375 - val_accuracy: 0.7746 - val_loss: 0.7099
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 653ms/step - accuracy: 0.9809 - loss: 0.0359 - val_accuracy: 0.8169 - val_loss: 0.6353
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9815 - loss: 0.0449 - val_accuracy: 0.8310 - val_loss: 0.5349
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9853 - loss: 0.0379 - val_accuracy: 0.8310 - val_loss: 0.5653
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9884 - loss: 0.0379 - val_accuracy: 0.9155 - val_loss: 0.3690
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 669ms/step - accuracy: 0.9923 - loss: 0.0262 - val_accuracy: 0.9014 - val_loss: 0.2831
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9921 - loss: 0.0332 - val_accuracy: 0.9437 - val_loss: 0.2795
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9947 - loss: 0.0419 - val_accuracy: 0.9718 - val_loss: 0.1508
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9764 - loss: 0.0470 - val_accuracy: 0.9718 - val_loss: 0.1510
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9918 - loss: 0.0303 - val_accuracy: 0.9577 - val_loss: 0.0988
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9835 - loss: 0.0450 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9839 - loss: 0.0349 - val_accuracy: 1.0000 - val_loss: 0.0213
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.9901 - loss: 0.0193 - val_accuracy: 0.9859 - val_loss: 0.0249
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9918 - loss: 0.0200 - val_accuracy: 0.9859 - val_loss: 0.0245
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9727 - loss: 0.1234 - val_accuracy: 0.9718 - val_loss: 0.1012
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9938 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0150
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9764 - loss: 0.0667 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9780 - loss: 0.0400 - val_accuracy: 0.9859 - val_loss: 0.0201
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9839 - loss: 0.0476 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9916 - loss: 0.0155 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9869 - loss: 0.0642 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9884 - loss: 0.0227 - val_accuracy: 1.0000 - val_loss: 0.0224
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 653ms/step - accuracy: 0.9878 - loss: 0.0299 - val_accuracy: 0.9859 - val_loss: 0.0245
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9907 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9861 - loss: 0.0323 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9876 - loss: 0.0503 - val_accuracy: 0.9859 - val_loss: 0.0332
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9892 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 664ms/step - accuracy: 0.9954 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9967 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 665ms/step - accuracy: 0.9782 - loss: 0.1121 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9966 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9951 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.9982 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0037
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9912 - loss: 0.0366 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9839 - loss: 0.0581 - val_accuracy: 0.9718 - val_loss: 0.0272
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9933 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9928 - loss: 0.0178 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9912 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9922 - loss: 0.0292 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9942 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9987 - loss: 0.0066 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 65/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9940 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 66/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9960 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 67/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9955 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 68/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9926 - loss: 0.0144 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 69/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9949 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 70/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9839 - loss: 0.0500 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 71/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9949 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 72/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9857 - loss: 0.0472 - val_accuracy: 1.0000 - val_loss: 0.0016
# Epoch 73/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9918 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 8.7983e-04
# Epoch 74/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9892 - loss: 0.0246 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 75/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9879 - loss: 0.0389 - val_accuracy: 1.0000 - val_loss: 9.6816e-04
# Epoch 76/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9960 - loss: 0.0227 - val_accuracy: 0.9859 - val_loss: 0.0292
# Epoch 77/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9974 - loss: 0.0051 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 78/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 1.0000 - val_loss: 9.2881e-04
# Epoch 79/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9991 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 80/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9996 - loss: 0.0043 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 81/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9844 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 82/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 655ms/step - accuracy: 0.9966 - loss: 0.0140 - val_accuracy: 0.9859 - val_loss: 0.0211
# Epoch 83/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9957 - loss: 0.0152 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 84/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 666ms/step - accuracy: 0.9886 - loss: 0.0213 - val_accuracy: 1.0000 - val_loss: 9.3292e-04
# Epoch 85/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 663ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 86/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9951 - loss: 0.0114 - val_accuracy: 1.0000 - val_loss: 7.7353e-04
# Epoch 87/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 669ms/step - accuracy: 0.9893 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 88/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9970 - loss: 0.0165 - val_accuracy: 0.9859 - val_loss: 0.0238
# Epoch 89/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.9859 - val_loss: 0.0118
# Epoch 90/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9988 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 91/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9872 - loss: 0.0270 - val_accuracy: 0.9859 - val_loss: 0.0252
# Epoch 92/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9921 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 93/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 654ms/step - accuracy: 0.9973 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 94/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 95/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 665ms/step - accuracy: 0.9966 - loss: 0.0140 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 96/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9856 - loss: 0.0259 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 97/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9972 - loss: 0.0091 - val_accuracy: 1.0000 - val_loss: 7.9860e-04
# Epoch 98/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 664ms/step - accuracy: 0.9988 - loss: 0.0080 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 99/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9996 - loss: 0.0050 - val_accuracy: 0.9859 - val_loss: 0.0170
# Epoch 100/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9919 - loss: 0.0234 - val_accuracy: 0.9577 - val_loss: 0.0904
# Epoch 101/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 666ms/step - accuracy: 0.9931 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 102/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 664ms/step - accuracy: 0.9879 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 103/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.9859 - val_loss: 0.0166
# Epoch 104/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9951 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 105/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 664ms/step - accuracy: 0.9978 - loss: 0.0097 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 106/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9986 - loss: 0.0041 - val_accuracy: 1.0000 - val_loss: 7.8979e-04
# Epoch 107/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 108/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9913 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 7.0016e-04
# Epoch 109/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9956 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 8.0519e-04
# Epoch 110/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9961 - loss: 0.0129 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 111/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9718 - val_loss: 0.0381
# Epoch 112/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9917 - loss: 0.0181 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 113/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9808 - loss: 0.0389 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 114/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9926 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 8.0281e-04
# Epoch 115/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9865 - loss: 0.0278 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 116/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9990 - loss: 0.0063 - val_accuracy: 0.9859 - val_loss: 0.0252
# Epoch 117/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9807 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 118/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9905 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 119/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9994 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 120/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9966 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 121/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9925 - loss: 0.0210 - val_accuracy: 0.9859 - val_loss: 0.0360
# Epoch 122/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9979 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0215
# Epoch 123/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9978 - loss: 0.0078 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 124/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9976 - loss: 0.0050 - val_accuracy: 0.9859 - val_loss: 0.0355
# Epoch 125/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9917 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 126/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 664ms/step - accuracy: 0.9998 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 127/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9996 - loss: 0.0063 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 128/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9968 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 129/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 657ms/step - accuracy: 0.9982 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 130/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9990 - loss: 0.0056 - val_accuracy: 0.9859 - val_loss: 0.0112
# Epoch 131/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 132/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 133/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9991 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 134/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 135/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 1.0000 - val_loss: 5.5348e-04
# Epoch 136/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9993 - loss: 0.0037 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 137/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 663ms/step - accuracy: 0.9958 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 7.7061e-04
# Epoch 138/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 659ms/step - accuracy: 0.9982 - loss: 0.0050 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 139/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9859 - val_loss: 0.0194
# Epoch 140/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9986 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 141/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 656ms/step - accuracy: 0.9955 - loss: 0.0089 - val_accuracy: 0.9859 - val_loss: 0.0556
# Epoch 142/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9857 - loss: 0.0317 - val_accuracy: 0.9859 - val_loss: 0.0209
# Epoch 143/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9958 - loss: 0.0066 - val_accuracy: 0.9859 - val_loss: 0.0393
# Epoch 144/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 660ms/step - accuracy: 0.9972 - loss: 0.0099 - val_accuracy: 1.0000 - val_loss: 7.6932e-04
# Epoch 145/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 661ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 9.0824e-04
# Epoch 146/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 658ms/step - accuracy: 0.9972 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 147/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 668ms/step - accuracy: 0.9931 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 148/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 667ms/step - accuracy: 0.9958 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 149/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 662ms/step - accuracy: 0.9980 - loss: 0.0084 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 150/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 12s 668ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 5.4873e-04
# CNN Model saved!

# %%
# Evaluate the CNN model on the test set
cnn_test_loss, cnn_test_accuracy = cnn_model.evaluate(cnn_test_ds)
print(f"CNN Test accuracy: {cnn_test_accuracy:.4f}")

# Plot CNN training history if available
if not SKIP_CNN_TRAINING:
    plt.figure(figsize=(12, 4))

    # Plot training & validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(cnn_history.history['accuracy'])
    plt.plot(cnn_history.history['val_accuracy'])
    plt.title('CNN Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss
    plt.subplot(1, 2, 2)
    plt.plot(cnn_history.history['loss'])
    plt.plot(cnn_history.history['val_loss'])
    plt.title('CNN Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()
else:
    print("Training history not available for loaded CNN model.")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9891 - loss: 0.0314
# CNN Test accuracy: 0.9859

# %%
# Get predictions using the CNN test dataset
cnn_y_pred = cnn_model.predict(cnn_test_ds)
cnn_predicted_classes = np.argmax(cnn_y_pred, axis=1)
true_classes = np.argmax(y_test_cat, axis=1)

# Calculate and display confusion matrix for CNN
cnn_cm = confusion_matrix(true_classes, cnn_predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cnn_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Glaucoma'], yticklabels=['Normal', 'Glaucoma'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('CNN Model Confusion Matrix')
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step

# %%
# Display classification report for CNN
print("CNN Classification Report:")
print(classification_report(true_classes, cnn_predicted_classes, target_names=['Normal', 'Glaucoma']))
# Out:
# CNN Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.97      0.98        31
#     Glaucoma       0.98      1.00      0.99        40
#
#     accuracy                           0.99        71
#    macro avg       0.99      0.98      0.99        71
# weighted avg       0.99      0.99      0.99        71

# %%
# Create TensorFlow datasets for training, validation, and testing for ResNet50 model
# For training data (with augmentation)
resnet_train_ds = tf.data.Dataset.from_generator(
    lambda: train_generator_fn(16),  # Smaller batch size for ResNet50
    output_signature=(
        tf.TensorSpec(shape=(None, img_height, img_width, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, 2), dtype=tf.float32)
    )
).prefetch(tf.data.AUTOTUNE)

# For validation and test data (NO augmentation)
resnet_val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val_cat)).batch(16).prefetch(tf.data.AUTOTUNE)
resnet_test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test_cat)).batch(16).prefetch(tf.data.AUTOTUNE)

# %%
if not SKIP_RESNET_TRAINING:
    # Load pre-trained ResNet50 model (without top classification layers)
    base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(img_height, img_width, 3))

    # Freeze the convolutional base
    base_model.trainable = False

    # Create a new model on top of the base model
    inputs = Input(shape=(img_height, img_width, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)  # Use global average pooling 

    # Add classification layers
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    x = Dense(256, activation='relu')(x)
    x = Dropout(0.4)(x)

    # Output layer
    outputs = Dense(2, activation='softmax')(x)

    # Create the transfer learning model
    resnet_model = Model(inputs=inputs, outputs=outputs)

    # Compile the model
    resnet_model.compile(
        optimizer=Adam(learning_rate=1e-4),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Model summary
    print("ResNet50 Transfer Learning Model Architecture:")
    resnet_model.summary()

    # Calculate steps per epoch based on dataset size and batch size
    batch_size = 16  # Using smaller batch size for ResNet50 training
    steps_per_epoch = np.ceil(len(X_train)/batch_size).astype(int)

    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        min_delta=0.001,
        mode='min',
        restore_best_weights=True
    )

    # Initial training phase with frozen base model
    print("Phase 1: Training only the top layers...")
    history_phase1 = resnet_model.fit(
        resnet_train_ds,
        steps_per_epoch=steps_per_epoch,
        epochs=15,  # Start with fewer epochs
        validation_data=resnet_val_ds,
        verbose=1,
        callbacks=[early_stopping] 
    )

    # Fine-tuning phase - unfreeze the last few layers of the base model
    print("Phase 2: Fine-tuning the model...")
    # Unfreeze the last 4 convolutional layers of ResNet50
    # ResNet50 has different layer structure than VGG16, so we're unfreezing the last few layers
    for layer in base_model.layers[-15:]:  # Adjusted for ResNet50 architecture
        layer.trainable = True

    # Recompile model with a lower learning rate for fine-tuning
    resnet_model.compile(
        optimizer=Adam(learning_rate=1e-5),  # Lower learning rate for fine-tuning
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    # Continue training with unfrozen layers
    history_phase2 = resnet_model.fit(
        resnet_train_ds,
        steps_per_epoch=steps_per_epoch,
        epochs=50,  # Train for more epochs during fine-tuning
        validation_data=resnet_val_ds,
        verbose=1,
        callbacks=[early_stopping] 
    )

    # Combine histories for plotting
    combined_history = {}
    combined_history['accuracy'] = history_phase1.history['accuracy'] + history_phase2.history['accuracy']
    combined_history['val_accuracy'] = history_phase1.history['val_accuracy'] + history_phase2.history['val_accuracy']
    combined_history['loss'] = history_phase1.history['loss'] + history_phase2.history['loss']
    combined_history['val_loss'] = history_phase1.history['val_loss'] + history_phase2.history['val_loss']

    resnet_history = type('obj', (object,), {'history': combined_history})

    # Save the model after training
    resnet_model.save(resnet_model_path)
    print("ResNet50 Model saved!")
else:
    # Create an empty history object to avoid errors in the plotting cell
    class EmptyHistory:
        def __init__(self):
            self.history = {'accuracy': [], 'val_accuracy': [], 'loss': [], 'val_loss': []}
    resnet_history = EmptyHistory()
    print("Skipped ResNet50 training as model was loaded from disk.")
# Out:
# ResNet50 Transfer Learning Model Architecture:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ resnet50 (Functional)           │ (None, 7, 7, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,770,690 (94.49 MB)
#  Trainable params: 1,181,954 (4.51 MB)
#  Non-trainable params: 23,588,736 (89.98 MB)
# Phase 1: Training only the top layers...
# Epoch 1/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 19s 432ms/step - accuracy: 0.5781 - loss: 0.6755 - val_accuracy: 0.4366 - val_loss: 0.9975
# Epoch 2/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.7372 - loss: 0.5722 - val_accuracy: 0.4366 - val_loss: 1.1064
# Epoch 3/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.7820 - loss: 0.4877 - val_accuracy: 0.4366 - val_loss: 1.2151
# Epoch 4/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.8144 - loss: 0.4524 - val_accuracy: 0.4366 - val_loss: 1.0029
# Epoch 5/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 406ms/step - accuracy: 0.8376 - loss: 0.4115 - val_accuracy: 0.4366 - val_loss: 0.8224
# Epoch 6/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.8372 - loss: 0.3944 - val_accuracy: 0.4366 - val_loss: 0.7210
# Epoch 7/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.8495 - loss: 0.3948 - val_accuracy: 0.7324 - val_loss: 0.6495
# Epoch 8/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 406ms/step - accuracy: 0.8595 - loss: 0.3496 - val_accuracy: 0.5915 - val_loss: 0.6328
# Epoch 9/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.8210 - loss: 0.3790 - val_accuracy: 0.6479 - val_loss: 0.6333
# Epoch 10/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 406ms/step - accuracy: 0.8663 - loss: 0.3281 - val_accuracy: 0.8310 - val_loss: 0.6024
# Epoch 11/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.8481 - loss: 0.3443 - val_accuracy: 0.6761 - val_loss: 0.5666
# Epoch 12/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 406ms/step - accuracy: 0.8863 - loss: 0.3247 - val_accuracy: 0.5915 - val_loss: 0.6523
# Epoch 13/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.8834 - loss: 0.3058 - val_accuracy: 0.5915 - val_loss: 0.6515
# Epoch 14/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 405ms/step - accuracy: 0.9017 - loss: 0.2761 - val_accuracy: 0.5634 - val_loss: 1.2674
# Epoch 15/15
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 15s 409ms/step - accuracy: 0.8880 - loss: 0.2849 - val_accuracy: 0.5634 - val_loss: 3.4831
# Phase 2: Fine-tuning the model...
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 23s 523ms/step - accuracy: 0.8277 - loss: 0.5042 - val_accuracy: 0.8451 - val_loss: 0.5226
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 504ms/step - accuracy: 0.8581 - loss: 0.3839 - val_accuracy: 0.4789 - val_loss: 0.7060
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 487ms/step - accuracy: 0.8509 - loss: 0.3626 - val_accuracy: 0.4789 - val_loss: 0.8271
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.8806 - loss: 0.3021 - val_accuracy: 0.4366 - val_loss: 2.7507
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 487ms/step - accuracy: 0.8959 - loss: 0.2741 - val_accuracy: 0.4366 - val_loss: 2.7370
# Epoch 6/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 492ms/step - accuracy: 0.8991 - loss: 0.2357 - val_accuracy: 0.4366 - val_loss: 4.3120
# Epoch 7/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 491ms/step - accuracy: 0.8896 - loss: 0.2751 - val_accuracy: 0.4366 - val_loss: 4.2946
# Epoch 8/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - accuracy: 0.8640 - loss: 0.2780 - val_accuracy: 0.6479 - val_loss: 0.7864
# Epoch 9/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 487ms/step - accuracy: 0.9150 - loss: 0.1992 - val_accuracy: 0.9014 - val_loss: 0.3072
# Epoch 10/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9080 - loss: 0.2116 - val_accuracy: 0.9296 - val_loss: 0.2773
# Epoch 11/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - accuracy: 0.9091 - loss: 0.2256 - val_accuracy: 0.5775 - val_loss: 1.0339
# Epoch 12/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 487ms/step - accuracy: 0.9214 - loss: 0.2554 - val_accuracy: 0.6901 - val_loss: 0.7170
# Epoch 13/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 487ms/step - accuracy: 0.8956 - loss: 0.2187 - val_accuracy: 0.8732 - val_loss: 0.3335
# Epoch 14/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 487ms/step - accuracy: 0.9388 - loss: 0.1752 - val_accuracy: 0.7183 - val_loss: 0.5985
# Epoch 15/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - accuracy: 0.9025 - loss: 0.2100 - val_accuracy: 0.9296 - val_loss: 0.2040
# Epoch 16/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9141 - loss: 0.2074 - val_accuracy: 0.8451 - val_loss: 0.3026
# Epoch 17/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 490ms/step - accuracy: 0.9465 - loss: 0.1578 - val_accuracy: 0.9014 - val_loss: 0.2367
# Epoch 18/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 492ms/step - accuracy: 0.9119 - loss: 0.2037 - val_accuracy: 0.9014 - val_loss: 0.2209
# Epoch 19/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9258 - loss: 0.1935 - val_accuracy: 0.5915 - val_loss: 1.5690
# Epoch 20/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 490ms/step - accuracy: 0.9243 - loss: 0.1960 - val_accuracy: 0.7606 - val_loss: 0.5576
# Epoch 21/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 493ms/step - accuracy: 0.9188 - loss: 0.2329 - val_accuracy: 0.8873 - val_loss: 0.2099
# Epoch 22/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9036 - loss: 0.2303 - val_accuracy: 0.7465 - val_loss: 0.5976
# Epoch 23/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9061 - loss: 0.2223 - val_accuracy: 0.6197 - val_loss: 1.1856
# Epoch 24/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9064 - loss: 0.2441 - val_accuracy: 0.7324 - val_loss: 0.7732
# Epoch 25/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 490ms/step - accuracy: 0.9122 - loss: 0.2175 - val_accuracy: 0.9296 - val_loss: 0.1833
# Epoch 26/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9244 - loss: 0.1875 - val_accuracy: 0.6761 - val_loss: 0.8732
# Epoch 27/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - accuracy: 0.9174 - loss: 0.2005 - val_accuracy: 0.8873 - val_loss: 0.2506
# Epoch 28/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 17s 487ms/step - accuracy: 0.9093 - loss: 0.1852 - val_accuracy: 0.8028 - val_loss: 0.5028
# Epoch 29/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9202 - loss: 0.2163 - val_accuracy: 0.9014 - val_loss: 0.2216
# Epoch 30/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 487ms/step - accuracy: 0.9054 - loss: 0.2060 - val_accuracy: 0.5070 - val_loss: 1.5831
# Epoch 31/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 487ms/step - accuracy: 0.9311 - loss: 0.1954 - val_accuracy: 0.5493 - val_loss: 1.5471
# Epoch 32/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - accuracy: 0.9034 - loss: 0.1953 - val_accuracy: 0.6197 - val_loss: 1.1696
# Epoch 33/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 489ms/step - accuracy: 0.9240 - loss: 0.1946 - val_accuracy: 0.8873 - val_loss: 0.3015
# Epoch 34/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 488ms/step - accuracy: 0.9236 - loss: 0.1593 - val_accuracy: 0.9155 - val_loss: 0.1921
# Epoch 35/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 18s 487ms/step - accuracy: 0.9341 - loss: 0.1539 - val_accuracy: 0.8873 - val_loss: 0.2543
# ResNet50 Model saved!

# %%
# Evaluate the ResNet50 model on the test set
resnet_test_loss, resnet_test_accuracy = resnet_model.evaluate(resnet_test_ds)
print(f"ResNet50 Test accuracy: {resnet_test_accuracy:.4f}")

# Plot ResNet50 training history if available
if not SKIP_RESNET_TRAINING:
    plt.figure(figsize=(12, 4))

    # Plot training & validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(resnet_history.history['accuracy'])
    plt.plot(resnet_history.history['val_accuracy'])
    plt.title('ResNet50 Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.axvline(x=20, color='r', linestyle='--')  # Mark where fine-tuning began
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss
    plt.subplot(1, 2, 2)
    plt.plot(resnet_history.history['loss'])
    plt.plot(resnet_history.history['val_loss'])
    plt.title('ResNet50 Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.axvline(x=20, color='r', linestyle='--')  # Mark where fine-tuning began
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()
else:
    print("Training history not available for loaded ResNet50 model.")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - accuracy: 0.9819 - loss: 0.1110
# ResNet50 Test accuracy: 0.9718

# %%
# Get predictions using the ResNet50 test dataset
resnet_y_pred = resnet_model.predict(resnet_test_ds)
resnet_predicted_classes = np.argmax(resnet_y_pred, axis=1)

# Calculate and display confusion matrix for ResNet50
resnet_cm = confusion_matrix(true_classes, resnet_predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(resnet_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Glaucoma'], yticklabels=['Normal', 'Glaucoma'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('ResNet50 Model Confusion Matrix')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 295ms/step

# %%
# Display classification report for ResNet50
print("ResNet50 Classification Report:")
print(classification_report(true_classes, resnet_predicted_classes, target_names=['Normal', 'Glaucoma']))
# Out:
# ResNet50 Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.94      0.97        31
#     Glaucoma       0.95      1.00      0.98        40
#
#     accuracy                           0.97        71
#    macro avg       0.98      0.97      0.97        71
# weighted avg       0.97      0.97      0.97        71
