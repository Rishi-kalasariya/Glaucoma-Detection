# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Input, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import confusion_matrix, classification_report

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Check if previously saved models exist
cnn_model_path = "/content/drive/MyDrive/IPML/glaucoma_cnn_model_acrima.keras"
vgg_model_path = "/content/drive/MyDrive/IPML/glaucoma_vgg16_model_acrima.keras"
resnet_model_path = "/content/drive/MyDrive/IPML/glaucoma_resnet50_model_acrima.keras"

if os.path.exists(cnn_model_path):
    print("Loading existing CNN model...")
    cnn_model = tf.keras.models.load_model(cnn_model_path)
    SKIP_CNN_TRAINING = True
else:
    print("No existing CNN model found. Will train a new CNN model.")
    SKIP_CNN_TRAINING = False

if os.path.exists(vgg_model_path):
    print("Loading existing VGG16 model...")
    vgg_model = tf.keras.models.load_model(vgg_model_path)
    SKIP_VGG_TRAINING = True
else:
    print("No existing VGG16 model found. Will train a new VGG16 model.")
    SKIP_VGG_TRAINING = False

if os.path.exists(resnet_model_path):
    print("Loading existing ResNet50 model...")
    resnet_model = tf.keras.models.load_model(resnet_model_path)
    SKIP_RESNET_TRAINING = True
else:
    print("No existing ResNet50 model found. Will train a new ResNet50 model.")
    SKIP_RESNET_TRAINING = False
# Out:
# No existing CNN model found. Will train a new CNN model.
# No existing VGG16 model found. Will train a new VGG16 model.
# No existing ResNet50 model found. Will train a new ResNet50 model.

# %%
# Set image dimensions (changed to match VGG16 requirements)
img_height, img_width = 224, 224

def load_and_preprocess_dataset(dataset_name, base_path="/content/drive/MyDrive/IPML/datasets"):
    """Load and preprocess images from a dataset"""
    images_glaucoma = []
    images_normal = []

    for category, image_list in zip(["glaucoma", "normal"], [images_glaucoma, images_normal]):
        dataset_path = os.path.join(base_path, dataset_name, category)

        if not os.path.exists(dataset_path):
            print(f"Dataset path for {dataset_name}/{category} not found.")
            continue

        image_files = [f for f in os.listdir(dataset_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

        # Load, convert color, resize, and normalize in one step
        image_list.extend([
            cv2.resize(
                cv2.cvtColor(cv2.imread(os.path.join(dataset_path, img_name)), cv2.COLOR_BGR2RGB),
                (img_height, img_width)
            ) / 255.0
            for img_name in image_files
        ])

    print(f"{dataset_name} images loaded and preprocessed successfully.")
    return np.array(images_glaucoma), np.array(images_normal)

# %%
def display_dataset_samples(dataset_name, images_glaucoma, images_normal, num_samples=4):
    """Display sample images from each category"""
    categories = ["Glaucoma", "Normal"]
    image_lists = [images_glaucoma, images_normal]

    for category, image_list in zip(categories, image_lists):
        if len(image_list) == 0:
            print(f"No images available for {dataset_name} - {category}")
            continue

        # Randomly select images (avoiding errors if list has fewer images)
        sample_images = random.choices(image_list, k=min(num_samples, len(image_list)))

        print(f"\nSample {dataset_name} {category} images:")
        plt.figure(figsize=(15, 10))

        for i, img in enumerate(sample_images):
            plt.subplot(1, num_samples, i + 1)
            # Since images are already normalized (0-1), we can display them directly
            plt.imshow(img)
            plt.axis("off")

        plt.show()

# %%
acrima_glaucoma, acrima_normal = load_and_preprocess_dataset("ACRIMA")
display_dataset_samples("ACRIMA", acrima_glaucoma, acrima_normal, num_samples=5)
print(f"ACRIMA - Glaucoma: {acrima_glaucoma.shape}, Normal: {acrima_normal.shape}")
# Out:
# ACRIMA images loaded and preprocessed successfully.
#
# Sample ACRIMA Glaucoma images:
# Sample ACRIMA Normal images:
# ACRIMA - Glaucoma: (396, 224, 224, 3), Normal: (309, 224, 224, 3)

# %%
# Print total images in each category
print(f"Total Glaucoma images: {len(acrima_glaucoma)}")
print(f"Total Normal images: {len(acrima_normal)}")

# Define class names and their counts
dataset_classes = np.array(["Glaucoma", "Normal"])
data_count = [len(acrima_glaucoma), len(acrima_normal)]

# Print total counts
print(f"Total images: {sum(data_count)}")
for category, count in zip(dataset_classes, data_count):
    print(f"Total {category} images: {count}")

# Plot class distribution
sns.set_style("darkgrid")
plt.figure(figsize=(6, 4))
sns.barplot(x=dataset_classes, y=data_count, hue=dataset_classes)
plt.xlabel("Category")
plt.ylabel("Number of Images")
plt.title("Distribution of Glaucoma & Normal Images")
plt.show()
# Out:
# Total Glaucoma images: 396
# Total Normal images: 309
# Total images: 705
# Total Glaucoma images: 396
# Total Normal images: 309

# %%
# Split data into train, validation and test sets
train_ratio = 0.8
val_ratio = 0.1  # Since test is 10%, val is also 10%

# Splitting Glaucoma images
X_train_glaucoma, temp_glaucoma = train_test_split(acrima_glaucoma, test_size=(1 - train_ratio), random_state=42)
X_val_glaucoma, X_test_glaucoma = train_test_split(temp_glaucoma, test_size=0.5, random_state=42)

# Splitting Normal images
X_train_normal, temp_normal = train_test_split(acrima_normal, test_size=(1 - train_ratio), random_state=42)
X_val_normal, X_test_normal = train_test_split(temp_normal, test_size=0.5, random_state=42)

# Print split counts
print(f"Train - Glaucoma: {len(X_train_glaucoma)}, Normal: {len(X_train_normal)}")
print(f"Validation - Glaucoma: {len(X_val_glaucoma)}, Normal: {len(X_val_normal)}")
print(f"Test - Glaucoma: {len(X_test_glaucoma)}, Normal: {len(X_test_normal)}")
# Out:
# Train - Glaucoma: 316, Normal: 247
# Validation - Glaucoma: 40, Normal: 31
# Test - Glaucoma: 40, Normal: 31

# %%
# Combine datasets and create labels
X_train = np.concatenate((X_train_glaucoma, X_train_normal), axis=0)
y_train = np.concatenate((np.ones(len(X_train_glaucoma)), np.zeros(len(X_train_normal))))

X_val = np.concatenate((X_val_glaucoma, X_val_normal), axis=0)
y_val = np.concatenate((np.ones(len(X_val_glaucoma)), np.zeros(len(X_val_normal))))

X_test = np.concatenate((X_test_glaucoma, X_test_normal), axis=0)
y_test = np.concatenate((np.ones(len(X_test_glaucoma)), np.zeros(len(X_test_normal))))

# Convert to categorical (one-hot encoding)
y_train_cat = to_categorical(y_train, num_classes=2)
y_val_cat = to_categorical(y_val, num_classes=2)
y_test_cat = to_categorical(y_test, num_classes=2)

# %%
# Define data augmentation (enhanced version for both models)
datagen = ImageDataGenerator(
    shear_range=0.15,
    zoom_range=0.2,
    horizontal_flip=True,
)

# Prepare augmentation (required for the generator)
datagen.fit(X_train)

# %%
# Create TensorFlow datasets for training, validation, and testing for CNN model
# For training data (with augmentation)
def train_generator_fn(batch_size=32):
    return datagen.flow(X_train, y_train_cat, batch_size=batch_size, shuffle=True)

cnn_train_ds = tf.data.Dataset.from_generator(
    lambda: train_generator_fn(32),
    output_signature=(
        tf.TensorSpec(shape=(None, img_height, img_width, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(None, 2), dtype=tf.float32)
    )
).prefetch(tf.data.AUTOTUNE)

# For validation data (NO augmentation)
cnn_val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val_cat)).batch(32).prefetch(tf.data.AUTOTUNE)

# For test data (NO augmentation)
cnn_test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test_cat)).batch(32).prefetch(tf.data.AUTOTUNE)

# %%
if not SKIP_CNN_TRAINING:
    # Define the CNN model
    cnn_model = Sequential()

    # Input Layer
    cnn_model.add(Input(shape=(img_height, img_width, 3)))

    # Convolutional and Pooling Layers (filters increasing deeper)
    cnn_model.add(Conv2D(16, (3, 3), activation='relu', padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

    cnn_model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

    cnn_model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(MaxPooling2D(pool_size=(2, 2)))

    # Flattening Layer
    cnn_model.add(Flatten())

    # Fully Connected Layers
    cnn_model.add(Dense(512, activation='relu'))
    cnn_model.add(BatchNormalization())
    cnn_model.add(Dropout(0.4))

    cnn_model.add(Dense(256, activation='relu'))
    cnn_model.add(Dropout(0.4))

    # Output Layer
    cnn_model.add(Dense(units=2, activation='softmax'))  # 2 classes (glaucoma, normal)

    # Compile the model
    cnn_model.compile(optimizer=Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])

    # Model summary
    print("CNN Model Architecture:")
    cnn_model.summary()
else:
    # Just display the model summary
    print("CNN Model Architecture (loaded from disk):")
    cnn_model.summary()
# Out:
# CNN Model Architecture:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    25,690,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           514 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 25,848,546 (98.60 MB)
#  Trainable params: 25,847,298 (98.60 MB)
#  Non-trainable params: 1,248 (4.88 KB)

# %%
if not SKIP_CNN_TRAINING:
    # Calculate steps per epoch based on dataset size and batch size
    batch_size = 32
    steps_per_epoch = np.ceil(len(X_train)/batch_size).astype(int)

    # Train the model using tf.data.Dataset
    cnn_history = cnn_model.fit(
        cnn_train_ds,
        steps_per_epoch=steps_per_epoch,
        epochs=150,
        validation_data=cnn_val_ds,
        verbose=1
    )

    # Save the model after training
    cnn_model.save(cnn_model_path)
    print("CNN Model saved!")
else:
    # Create an empty history object to avoid errors in the plotting cell
    class EmptyHistory:
        def __init__(self):
            self.history = {'accuracy': [], 'val_accuracy': [], 'loss': [], 'val_loss': []}
    cnn_history = EmptyHistory()
    print("Skipped CNN training as model was loaded from disk.")
# Out:
# Epoch 1/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 23s 700ms/step - accuracy: 0.7660 - loss: 0.6495 - val_accuracy: 0.4366 - val_loss: 0.7319
# Epoch 2/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 352ms/step - accuracy: 0.8760 - loss: 0.3426 - val_accuracy: 0.4366 - val_loss: 0.7476
# Epoch 3/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.9055 - loss: 0.2107 - val_accuracy: 0.4366 - val_loss: 0.7165
# Epoch 4/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 8s 465ms/step - accuracy: 0.9383 - loss: 0.1724 - val_accuracy: 0.6479 - val_loss: 0.6747
# Epoch 5/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 341ms/step - accuracy: 0.9508 - loss: 0.1459 - val_accuracy: 0.6338 - val_loss: 0.6743
# Epoch 6/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 410ms/step - accuracy: 0.9553 - loss: 0.1161 - val_accuracy: 0.6479 - val_loss: 0.6707
# Epoch 7/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - accuracy: 0.9631 - loss: 0.0960 - val_accuracy: 0.7465 - val_loss: 0.6154
# Epoch 8/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 400ms/step - accuracy: 0.9558 - loss: 0.1320 - val_accuracy: 0.7746 - val_loss: 0.6030
# Epoch 9/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - accuracy: 0.9540 - loss: 0.1335 - val_accuracy: 0.6620 - val_loss: 0.5800
# Epoch 10/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 394ms/step - accuracy: 0.9589 - loss: 0.1263 - val_accuracy: 0.7606 - val_loss: 0.5473
# Epoch 11/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.9604 - loss: 0.0970 - val_accuracy: 0.6197 - val_loss: 0.6802
# Epoch 12/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 384ms/step - accuracy: 0.9742 - loss: 0.0753 - val_accuracy: 0.7746 - val_loss: 0.5383
# Epoch 13/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - accuracy: 0.9806 - loss: 0.0656 - val_accuracy: 0.8028 - val_loss: 0.5310
# Epoch 14/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.9822 - loss: 0.0556 - val_accuracy: 0.7324 - val_loss: 0.5978
# Epoch 15/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.9497 - loss: 0.1330 - val_accuracy: 0.8028 - val_loss: 0.5029
# Epoch 16/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.9860 - loss: 0.0490 - val_accuracy: 0.7746 - val_loss: 0.5521
# Epoch 17/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 389ms/step - accuracy: 0.9782 - loss: 0.0747 - val_accuracy: 0.8310 - val_loss: 0.4136
# Epoch 18/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 311ms/step - accuracy: 0.9896 - loss: 0.0377 - val_accuracy: 0.8310 - val_loss: 0.3834
# Epoch 19/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.9836 - loss: 0.0506 - val_accuracy: 0.7746 - val_loss: 0.4692
# Epoch 20/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.9763 - loss: 0.0859 - val_accuracy: 0.8028 - val_loss: 0.4462
# Epoch 21/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.9858 - loss: 0.0274 - val_accuracy: 0.8310 - val_loss: 0.3421
# Epoch 22/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - accuracy: 0.9799 - loss: 0.0872 - val_accuracy: 0.8451 - val_loss: 0.2808
# Epoch 23/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.9835 - loss: 0.0540 - val_accuracy: 0.9437 - val_loss: 0.1556
# Epoch 24/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.9780 - loss: 0.0505 - val_accuracy: 0.8873 - val_loss: 0.2320
# Epoch 25/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 394ms/step - accuracy: 0.9842 - loss: 0.0491 - val_accuracy: 0.9296 - val_loss: 0.1326
# Epoch 26/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - accuracy: 0.9887 - loss: 0.0423 - val_accuracy: 0.9155 - val_loss: 0.1746
# Epoch 27/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 358ms/step - accuracy: 0.9755 - loss: 0.0663 - val_accuracy: 0.9437 - val_loss: 0.1523
# Epoch 28/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 344ms/step - accuracy: 0.9878 - loss: 0.0365 - val_accuracy: 0.9155 - val_loss: 0.2646
# Epoch 29/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 0.9839 - loss: 0.0344 - val_accuracy: 0.9437 - val_loss: 0.1193
# Epoch 30/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.9911 - loss: 0.0351 - val_accuracy: 0.9296 - val_loss: 0.1849
# Epoch 31/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.9895 - loss: 0.0523 - val_accuracy: 0.9437 - val_loss: 0.1419
# Epoch 32/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 402ms/step - accuracy: 0.9853 - loss: 0.0371 - val_accuracy: 0.9437 - val_loss: 0.0843
# Epoch 33/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - accuracy: 0.9921 - loss: 0.0182 - val_accuracy: 0.9437 - val_loss: 0.1649
# Epoch 34/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.9860 - loss: 0.0476 - val_accuracy: 0.9859 - val_loss: 0.0493
# Epoch 35/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.9924 - loss: 0.0280 - val_accuracy: 0.9577 - val_loss: 0.0673
# Epoch 36/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 401ms/step - accuracy: 0.9968 - loss: 0.0158 - val_accuracy: 0.9859 - val_loss: 0.0381
# Epoch 37/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 306ms/step - accuracy: 0.9913 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 38/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.9727 - loss: 0.0580 - val_accuracy: 0.9718 - val_loss: 0.0572
# Epoch 39/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.9811 - loss: 0.0434 - val_accuracy: 0.9859 - val_loss: 0.0568
# Epoch 40/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 361ms/step - accuracy: 0.9889 - loss: 0.0197 - val_accuracy: 0.9859 - val_loss: 0.0310
# Epoch 41/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 333ms/step - accuracy: 0.9906 - loss: 0.0207 - val_accuracy: 0.9859 - val_loss: 0.0263
# Epoch 42/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 325ms/step - accuracy: 0.9898 - loss: 0.0250 - val_accuracy: 0.9859 - val_loss: 0.0629
# Epoch 43/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 374ms/step - accuracy: 0.9942 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 44/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9789 - loss: 0.0500 - val_accuracy: 0.9859 - val_loss: 0.0438
# Epoch 45/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 398ms/step - accuracy: 0.9837 - loss: 0.0866 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 46/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - accuracy: 0.9987 - loss: 0.0125 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 47/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.9956 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 48/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - accuracy: 0.9890 - loss: 0.0407 - val_accuracy: 0.9859 - val_loss: 0.0183
# Epoch 49/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.9951 - loss: 0.0140 - val_accuracy: 0.9859 - val_loss: 0.0203
# Epoch 50/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 1.0000 - loss: 0.0079 - val_accuracy: 0.9859 - val_loss: 0.0164
# Epoch 51/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 400ms/step - accuracy: 0.9944 - loss: 0.0199 - val_accuracy: 0.9859 - val_loss: 0.0299
# Epoch 52/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 311ms/step - accuracy: 0.9909 - loss: 0.0173 - val_accuracy: 0.9718 - val_loss: 0.0492
# Epoch 53/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.9979 - loss: 0.0090 - val_accuracy: 0.9577 - val_loss: 0.0684
# Epoch 54/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 305ms/step - accuracy: 0.9929 - loss: 0.0269 - val_accuracy: 0.9718 - val_loss: 0.0618
# Epoch 55/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 335ms/step - accuracy: 0.9931 - loss: 0.0196 - val_accuracy: 0.9859 - val_loss: 0.0566
# Epoch 56/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.9898 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0124
# Epoch 57/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.9859 - val_loss: 0.0291
# Epoch 58/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 390ms/step - accuracy: 0.9946 - loss: 0.0203 - val_accuracy: 0.9859 - val_loss: 0.0572
# Epoch 59/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 0.9957 - loss: 0.0142 - val_accuracy: 0.9859 - val_loss: 0.0237
# Epoch 60/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 396ms/step - accuracy: 0.9844 - loss: 0.0329 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 61/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 0.9854 - loss: 0.0281 - val_accuracy: 0.9718 - val_loss: 0.0505
# Epoch 62/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 395ms/step - accuracy: 0.9953 - loss: 0.0163 - val_accuracy: 0.9859 - val_loss: 0.0435
# Epoch 63/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.9847 - loss: 0.0265 - val_accuracy: 0.9859 - val_loss: 0.0622
# Epoch 64/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.9908 - loss: 0.0180 - val_accuracy: 0.9859 - val_loss: 0.0524
# Epoch 65/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 308ms/step - accuracy: 0.9858 - loss: 0.0534 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 66/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 375ms/step - accuracy: 0.9828 - loss: 0.0546 - val_accuracy: 0.9859 - val_loss: 0.0341
# Epoch 67/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.9911 - loss: 0.0290 - val_accuracy: 0.9859 - val_loss: 0.0337
# Epoch 68/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.9959 - loss: 0.0107 - val_accuracy: 0.9859 - val_loss: 0.0220
# Epoch 69/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 357ms/step - accuracy: 0.9981 - loss: 0.0114 - val_accuracy: 0.9859 - val_loss: 0.0386
# Epoch 70/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 318ms/step - accuracy: 0.9941 - loss: 0.0144 - val_accuracy: 0.9859 - val_loss: 0.0354
# Epoch 71/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 386ms/step - accuracy: 0.9908 - loss: 0.0172 - val_accuracy: 0.9859 - val_loss: 0.0382
# Epoch 72/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - accuracy: 0.9956 - loss: 0.0103 - val_accuracy: 0.9718 - val_loss: 0.0608
# Epoch 73/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 406ms/step - accuracy: 0.9944 - loss: 0.0195 - val_accuracy: 0.9859 - val_loss: 0.0179
# Epoch 74/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 310ms/step - accuracy: 0.9907 - loss: 0.0262 - val_accuracy: 0.9859 - val_loss: 0.0343
# Epoch 75/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 398ms/step - accuracy: 0.9978 - loss: 0.0083 - val_accuracy: 0.9859 - val_loss: 0.0305
# Epoch 76/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 0.9970 - loss: 0.0117 - val_accuracy: 0.9718 - val_loss: 0.1209
# Epoch 77/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.9915 - loss: 0.0155 - val_accuracy: 0.9859 - val_loss: 0.0168
# Epoch 78/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.9930 - loss: 0.0186 - val_accuracy: 0.9718 - val_loss: 0.0662
# Epoch 79/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.9912 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 80/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 314ms/step - accuracy: 0.9977 - loss: 0.0059 - val_accuracy: 0.9577 - val_loss: 0.1670
# Epoch 81/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 354ms/step - accuracy: 0.9920 - loss: 0.0175 - val_accuracy: 0.9718 - val_loss: 0.0424
# Epoch 82/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 342ms/step - accuracy: 0.9957 - loss: 0.0132 - val_accuracy: 0.9718 - val_loss: 0.0377
# Epoch 83/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 320ms/step - accuracy: 0.9877 - loss: 0.0247 - val_accuracy: 0.9718 - val_loss: 0.0510
# Epoch 84/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 380ms/step - accuracy: 0.9939 - loss: 0.0211 - val_accuracy: 0.9859 - val_loss: 0.0602
# Epoch 85/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9892 - loss: 0.0278 - val_accuracy: 0.9718 - val_loss: 0.0578
# Epoch 86/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 400ms/step - accuracy: 0.9796 - loss: 0.0483 - val_accuracy: 0.9859 - val_loss: 0.0469
# Epoch 87/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 321ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9577 - val_loss: 0.0895
# Epoch 88/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 406ms/step - accuracy: 0.9916 - loss: 0.0150 - val_accuracy: 0.9718 - val_loss: 0.1281
# Epoch 89/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 316ms/step - accuracy: 0.9895 - loss: 0.0236 - val_accuracy: 0.9859 - val_loss: 0.0336
# Epoch 90/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 408ms/step - accuracy: 0.9878 - loss: 0.0283 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 91/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.9993 - loss: 0.0085 - val_accuracy: 0.9718 - val_loss: 0.0419
# Epoch 92/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 402ms/step - accuracy: 0.9973 - loss: 0.0107 - val_accuracy: 0.9718 - val_loss: 0.0617
# Epoch 93/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 315ms/step - accuracy: 0.9903 - loss: 0.0187 - val_accuracy: 0.9577 - val_loss: 0.1711
# Epoch 94/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 400ms/step - accuracy: 0.9910 - loss: 0.0216 - val_accuracy: 0.9577 - val_loss: 0.1056
# Epoch 95/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 317ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9718 - val_loss: 0.0625
# Epoch 96/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 379ms/step - accuracy: 0.9939 - loss: 0.0220 - val_accuracy: 0.9859 - val_loss: 0.0281
# Epoch 97/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.9923 - loss: 0.0336 - val_accuracy: 0.9859 - val_loss: 0.0355
# Epoch 98/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 336ms/step - accuracy: 0.9890 - loss: 0.0326 - val_accuracy: 0.9718 - val_loss: 0.0420
# Epoch 99/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 359ms/step - accuracy: 0.9832 - loss: 0.0341 - val_accuracy: 0.9718 - val_loss: 0.0773
# Epoch 100/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.9934 - loss: 0.0182 - val_accuracy: 0.9718 - val_loss: 0.1970
# Epoch 101/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.9971 - loss: 0.0120 - val_accuracy: 0.9577 - val_loss: 0.0942
# Epoch 102/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.9954 - loss: 0.0181 - val_accuracy: 0.9859 - val_loss: 0.0216
# Epoch 103/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.9651 - loss: 0.1058 - val_accuracy: 0.9718 - val_loss: 0.0857
# Epoch 104/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.9912 - loss: 0.0399 - val_accuracy: 0.9859 - val_loss: 0.0296
# Epoch 105/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 403ms/step - accuracy: 0.9984 - loss: 0.0095 - val_accuracy: 0.9859 - val_loss: 0.0528
# Epoch 106/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 0.9974 - loss: 0.0084 - val_accuracy: 0.9718 - val_loss: 0.0731
# Epoch 107/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 392ms/step - accuracy: 0.9995 - loss: 0.0054 - val_accuracy: 0.9859 - val_loss: 0.0561
# Epoch 108/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.9946 - loss: 0.0136 - val_accuracy: 0.9718 - val_loss: 0.1274
# Epoch 109/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 408ms/step - accuracy: 0.9991 - loss: 0.0044 - val_accuracy: 0.9859 - val_loss: 0.0574
# Epoch 110/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 313ms/step - accuracy: 0.9970 - loss: 0.0115 - val_accuracy: 0.9859 - val_loss: 0.0196
# Epoch 111/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 360ms/step - accuracy: 0.9882 - loss: 0.0378 - val_accuracy: 0.9859 - val_loss: 0.0361
# Epoch 112/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 332ms/step - accuracy: 0.9963 - loss: 0.0127 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 113/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9984 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 114/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 375ms/step - accuracy: 0.9974 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 115/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9937 - loss: 0.0118 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 116/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 398ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 117/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 309ms/step - accuracy: 0.9972 - loss: 0.0063 - val_accuracy: 0.9859 - val_loss: 0.0307
# Epoch 118/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 397ms/step - accuracy: 0.9979 - loss: 0.0043 - val_accuracy: 0.9859 - val_loss: 0.0624
# Epoch 119/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.9968 - loss: 0.0120 - val_accuracy: 0.9859 - val_loss: 0.0192
# Epoch 120/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 405ms/step - accuracy: 0.9969 - loss: 0.0071 - val_accuracy: 0.9859 - val_loss: 0.0270
# Epoch 121/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - accuracy: 0.9972 - loss: 0.0051 - val_accuracy: 0.9859 - val_loss: 0.0119
# Epoch 122/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 395ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 123/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 313ms/step - accuracy: 0.9923 - loss: 0.0095 - val_accuracy: 0.9859 - val_loss: 0.0118
# Epoch 124/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 355ms/step - accuracy: 0.9995 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 125/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 326ms/step - accuracy: 0.9976 - loss: 0.0062 - val_accuracy: 0.9859 - val_loss: 0.0468
# Epoch 126/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 323ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9859 - val_loss: 0.0506
# Epoch 127/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 368ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9859 - val_loss: 0.0488
# Epoch 128/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 310ms/step - accuracy: 0.9962 - loss: 0.0116 - val_accuracy: 0.9859 - val_loss: 0.0185
# Epoch 129/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.9961 - loss: 0.0058 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 130/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 304ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 131/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 388ms/step - accuracy: 0.9921 - loss: 0.0219 - val_accuracy: 0.9859 - val_loss: 0.0187
# Epoch 132/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 302ms/step - accuracy: 0.9942 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 133/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 391ms/step - accuracy: 0.9960 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 134/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.9940 - loss: 0.0133 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 135/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.9972 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 9.0749e-04
# Epoch 136/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 303ms/step - accuracy: 0.9938 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 137/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 338ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 138/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 343ms/step - accuracy: 0.9993 - loss: 0.0032 - val_accuracy: 0.9718 - val_loss: 0.0430
# Epoch 139/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 309ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9577 - val_loss: 0.0840
# Epoch 140/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 389ms/step - accuracy: 0.9942 - loss: 0.0110 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 141/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 308ms/step - accuracy: 0.9966 - loss: 0.0151 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 142/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 399ms/step - accuracy: 0.9940 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 143/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 301ms/step - accuracy: 0.9942 - loss: 0.0109 - val_accuracy: 0.9718 - val_loss: 0.0342
# Epoch 144/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 383ms/step - accuracy: 0.9938 - loss: 0.0100 - val_accuracy: 0.9859 - val_loss: 0.0389
# Epoch 145/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 305ms/step - accuracy: 0.9975 - loss: 0.0047 - val_accuracy: 0.9859 - val_loss: 0.0406
# Epoch 146/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 7s 387ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.9718 - val_loss: 0.1583
# Epoch 147/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 312ms/step - accuracy: 0.9968 - loss: 0.0096 - val_accuracy: 0.9859 - val_loss: 0.0341
# Epoch 148/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 362ms/step - accuracy: 0.9972 - loss: 0.0095 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 149/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 6s 327ms/step - accuracy: 0.9966 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 150/150
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 5s 308ms/step - accuracy: 0.9955 - loss: 0.0149 - val_accuracy: 0.9718 - val_loss: 0.0378
# CNN Model saved!

# %%
# Evaluate the CNN model on the test set
cnn_test_loss, cnn_test_accuracy = cnn_model.evaluate(cnn_test_ds)
print(f"CNN Test accuracy: {cnn_test_accuracy:.4f}")

# Evaluate the CNN model on the test set
cnn_test_loss, cnn_test_accuracy = cnn_model.evaluate(cnn_test_ds)
print(f"CNN Test accuracy: {cnn_test_accuracy:.4f}")

# Plot CNN training history if available
if not SKIP_CNN_TRAINING:
    plt.figure(figsize=(12, 4))

    # Plot training & validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(cnn_history.history['accuracy'])
    plt.plot(cnn_history.history['val_accuracy'])
    plt.title('CNN Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    # Plot training & validation loss
    plt.subplot(1, 2, 2)
    plt.plot(cnn_history.history['loss'])
    plt.plot(cnn_history.history['val_loss'])
    plt.title('CNN Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()
else:
    print("Training history not available for loaded CNN model.")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9820 - loss: 0.0759
# CNN Test accuracy: 0.9718
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9820 - loss: 0.0759
# CNN Test accuracy: 0.9718

# %%
# Get predictions using the CNN test dataset
cnn_y_pred = cnn_model.predict(cnn_test_ds)
cnn_predicted_classes = np.argmax(cnn_y_pred, axis=1)
true_classes = np.argmax(y_test_cat, axis=1)

# Calculate and display confusion matrix for CNN
cnn_cm = confusion_matrix(true_classes, cnn_predicted_classes)
plt.figure(figsize=(8, 6))
sns.heatmap(cnn_cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Normal', 'Glaucoma'], yticklabels=['Normal', 'Glaucoma'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('CNN Model Confusion Matrix')
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step

# %%
# Display classification report for CNN
print("CNN Classification Report:")
print(classification_report(true_classes, cnn_predicted_classes, target_names=['Normal', 'Glaucoma']))
# Out:
# CNN Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.94      0.97        31
#     Glaucoma       0.95      1.00      0.98        40
#
#     accuracy                           0.97        71
#    macro avg       0.98      0.97      0.97        71
# weighted avg       0.97      0.97      0.97        71
